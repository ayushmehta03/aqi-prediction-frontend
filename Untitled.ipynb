# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
city = pd.read_csv("city_day.csv")
city.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
#### Extra Added ###
city['Date'] = city['Date'].str.split("-").str[1]
city['Date']=city['Date'].astype(int)
city = city.rename(columns={"Date": "Month"})
city.head()
# Out:
#         City  Month  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad      1    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad      1    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad      1    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad      1    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad      1    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %% [markdown]
# ## DROP AQI BUCKET(NOT NECCESSARY)

# %%
city.drop("AQI_Bucket",axis=1,inplace=True)
city.head()
# Out:
#         City  Month  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad      1    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad      1    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad      1    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad      1    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad      1    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI
# 0  133.36     0.00     0.02    0.00  NaN
# 1   34.06     3.68     5.50    3.77  NaN
# 2   30.70     6.80    16.40    2.25  NaN
# 3   36.08     4.43    10.14    1.00  NaN
# 4   39.31     7.01    18.89    2.78  NaN

# %% [markdown]
# # Cleaning dataset

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  object
#  1   Month    29531 non-null  int32
#  2   PM2.5    24933 non-null  float64
#  3   PM10     18391 non-null  float64
#  4   NO       25949 non-null  float64
#  5   NO2      25946 non-null  float64
#  6   NOx      25346 non-null  float64
#  7   NH3      19203 non-null  float64
#  8   CO       27472 non-null  float64
#  9   SO2      25677 non-null  float64
#  10  O3       25509 non-null  float64
#  11  Benzene  23908 non-null  float64
#  12  Toluene  21490 non-null  float64
#  13  Xylene   11422 non-null  float64
#  14  AQI      24850 non-null  float64
# dtypes: float64(13), int32(1), object(1)
# memory usage: 3.3+ MB

# %%
city.isnull().sum()
# Out:
# City           0
# Month          0
# PM2.5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# Xylene     18109
# AQI         4681
# dtype: int64

# %%
city.shape
# Out:
# (29531, 15)

# %%
null_percentage = city.isnull().mean() * 100
print(null_percentage)
# Out:
# City        0.000000
# Month       0.000000
# PM2.5      15.570079
# PM10       37.723071
# NO         12.129626
# NO2        12.139785
# NOx        14.171549
# NH3        34.973418
# CO          6.972334
# SO2        13.050692
# O3         13.619586
# Benzene    19.041008
# Toluene    27.229014
# Xylene     61.322001
# AQI        15.851139
# dtype: float64

# %% [markdown]
# ## We'll drop all the features having null values more than 30%

# %%
threshold = 0.30
city = city.loc[:, city.isnull().mean() <= threshold]

# %%
city.isnull().mean() * 100
# Out:
# City        0.000000
# Month       0.000000
# PM2.5      15.570079
# NO         12.129626
# NO2        12.139785
# NOx        14.171549
# CO          6.972334
# SO2        13.050692
# O3         13.619586
# Benzene    19.041008
# Toluene    27.229014
# AQI        15.851139
# dtype: float64

# %%
city.shape
# Out:
# (29531, 12)

# %% [markdown]
# ### Relacing null values by three methods and choosed the best one
# 1. Mean Imputation
# 2. Median Imputation
# 3. Random Sample Imputation : Remove null values and fill those null values by taking random samples from the dataset

# %%
def impute_nan(df,variable):
    
    df[variable+"_median"] = df[variable].fillna(df[variable].median())
    df[variable+"_mean"] = df[variable].fillna(df[variable].mean())
    df[variable+"_random"] = df[variable]
    # It will have the random sample to fill nan values
    random_sample = df[variable].dropna().sample(df[variable].isnull().sum(),
                                                 random_state=0)
    # Pandas need to have same index in order to merge the dataset
    random_sample.index = df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable+'_random'] = random_sample

    fig = plt.figure()
    ax = fig.add_subplot([1.2,1.2,1.2,1.2])
    
    
    df[variable+"_mean"].plot(kind='kde',ax=ax, color='orange')
    df[variable+"_median"].plot(kind='kde',ax=ax, color='green')
    df[variable+"_random"].plot(kind='kde',ax=ax, color='deeppink')

    df[variable].plot(kind='kde', ax=ax, color='black')
    
    lines, labels = ax.get_legend_handles_labels()
    ax.legend(lines, labels, loc = 'best')

# %%
mean = city["PM2.5"].mean()
median = city["PM2.5"].median()
(mean, median)
# Out:
# (67.45057794890306, 48.57)

# %%
impute_nan(city,"PM2.5")

# %%
# We'll take random(performing best)
city.drop(["PM2.5", "PM2.5_median", "PM2.5_mean"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month     NO    NO2    NOx     CO    SO2      O3  Benzene  \
# 0  Ahmedabad      1   0.92  18.22  17.15   0.92  27.64  133.36     0.00
# 1  Ahmedabad      1   0.97  15.69  16.46   0.97  24.55   34.06     3.68
# 2  Ahmedabad      1  17.40  19.30  29.70  17.40  29.07   30.70     6.80
# 3  Ahmedabad      1   1.70  18.48  17.97   1.70  18.59   36.08     4.43
# 4  Ahmedabad      1  22.10  21.42  37.76  22.10  39.33   39.31     7.01
#
#    Toluene  AQI  PM2.5_random
# 0     0.02  NaN         51.84
# 1     5.50  NaN         38.26
# 2    16.40  NaN         53.84
# 3    10.14  NaN         11.75
# 4    18.89  NaN         31.80

# %%
city.isnull().sum()
# Out:
# City               0
# Month              0
# NO              3582
# NO2             3585
# NOx             4185
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# AQI             4681
# PM2.5_random       0
# dtype: int64

# %% [markdown]
# #### changing NO_day

# %%
mean = city["NO"].mean()
median = city["NO"].median()
(mean, median)
# Out:
# (17.574729662029362, 9.89)

# %%
impute_nan(city,"NO")

# %%
# We'll take random(performing best)
city.drop(["NO", "NO_median", "NO_mean"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month    NO2    NOx     CO    SO2      O3  Benzene  Toluene  \
# 0  Ahmedabad      1  18.22  17.15   0.92  27.64  133.36     0.00     0.02
# 1  Ahmedabad      1  15.69  16.46   0.97  24.55   34.06     3.68     5.50
# 2  Ahmedabad      1  19.30  29.70  17.40  29.07   30.70     6.80    16.40
# 3  Ahmedabad      1  18.48  17.97   1.70  18.59   36.08     4.43    10.14
# 4  Ahmedabad      1  21.42  37.76  22.10  39.33   39.31     7.01    18.89
#
#    AQI  PM2.5_random  NO_random
# 0  NaN         51.84       0.92
# 1  NaN         38.26       0.97
# 2  NaN         53.84      17.40
# 3  NaN         11.75       1.70
# 4  NaN         31.80      22.10

# %%
city.isnull().sum()
# Out:
# City               0
# Month              0
# NO2             3585
# NOx             4185
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# AQI             4681
# PM2.5_random       0
# NO_random          0
# dtype: int64

# %% [markdown]
# #### Changing NO2_day

# %%
mean = city["NO2"].mean()
median = city["NO2"].median()
(mean, median)
# Out:
# (28.560659061126955, 21.69)

# %%
impute_nan(city,"NO2")

# %%
# We'll take random(performing best)
city.drop(["NO2", "NO2_median", "NO2_mean"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month    NOx     CO    SO2      O3  Benzene  Toluene  AQI  \
# 0  Ahmedabad      1  17.15   0.92  27.64  133.36     0.00     0.02  NaN
# 1  Ahmedabad      1  16.46   0.97  24.55   34.06     3.68     5.50  NaN
# 2  Ahmedabad      1  29.70  17.40  29.07   30.70     6.80    16.40  NaN
# 3  Ahmedabad      1  17.97   1.70  18.59   36.08     4.43    10.14  NaN
# 4  Ahmedabad      1  37.76  22.10  39.33   39.31     7.01    18.89  NaN
#
#    PM2.5_random  NO_random  NO2_random
# 0         51.84       0.92       18.22
# 1         38.26       0.97       15.69
# 2         53.84      17.40       19.30
# 3         11.75       1.70       18.48
# 4         31.80      22.10       21.42

# %%
city.isnull().sum()
# Out:
# City               0
# Month              0
# NOx             4185
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# AQI             4681
# PM2.5_random       0
# NO_random          0
# NO2_random         0
# dtype: int64

# %% [markdown]
# #### Changing NOx

# %%
mean = city["NOx"].mean()
median = city["NOx"].median()
(mean, median)
# Out:
# (32.30912333307031, 23.52)

# %%
impute_nan(city,"NOx")

# %%
# We'll take random(performing best)
city.drop(["NOx", "NOx_median", "NOx_mean"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month     CO    SO2      O3  Benzene  Toluene  AQI  \
# 0  Ahmedabad      1   0.92  27.64  133.36     0.00     0.02  NaN
# 1  Ahmedabad      1   0.97  24.55   34.06     3.68     5.50  NaN
# 2  Ahmedabad      1  17.40  29.07   30.70     6.80    16.40  NaN
# 3  Ahmedabad      1   1.70  18.59   36.08     4.43    10.14  NaN
# 4  Ahmedabad      1  22.10  39.33   39.31     7.01    18.89  NaN
#
#    PM2.5_random  NO_random  NO2_random  NOx_random
# 0         51.84       0.92       18.22       17.15
# 1         38.26       0.97       15.69       16.46
# 2         53.84      17.40       19.30       29.70
# 3         11.75       1.70       18.48       17.97
# 4         31.80      22.10       21.42       37.76

# %%
city.isnull().sum()
# Out:
# City               0
# Month              0
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# AQI             4681
# PM2.5_random       0
# NO_random          0
# NO2_random         0
# NOx_random         0
# dtype: int64

# %% [markdown]
# #### Changing CO

# %%
mean = city["CO"].mean()
median = city["CO"].median()
(mean, median)
# Out:
# (2.2485982090856145, 0.89)

# %%
impute_nan(city,"CO")

# %%
# We'll take mean
city.drop(["CO", "CO_random", "CO_median"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month    SO2      O3  Benzene  Toluene  AQI  PM2.5_random  \
# 0  Ahmedabad      1  27.64  133.36     0.00     0.02  NaN         51.84
# 1  Ahmedabad      1  24.55   34.06     3.68     5.50  NaN         38.26
# 2  Ahmedabad      1  29.07   30.70     6.80    16.40  NaN         53.84
# 3  Ahmedabad      1  18.59   36.08     4.43    10.14  NaN         11.75
# 4  Ahmedabad      1  39.33   39.31     7.01    18.89  NaN         31.80
#
#    NO_random  NO2_random  NOx_random  CO_mean
# 0       0.92       18.22       17.15     0.92
# 1       0.97       15.69       16.46     0.97
# 2      17.40       19.30       29.70    17.40
# 3       1.70       18.48       17.97     1.70
# 4      22.10       21.42       37.76    22.10

# %%
city.isnull().sum()
# Out:
# City               0
# Month              0
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# AQI             4681
# PM2.5_random       0
# NO_random          0
# NO2_random         0
# NOx_random         0
# CO_mean            0
# dtype: int64

# %%
def impute_nan_grp(df, variables):
   
    # Create subplots for 4 variables
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # 2x2 grid for 4 variables
    axs = axs.ravel()  # Flatten the array of axes for easier indexing
    
    for idx, variable in enumerate(variables):
        median = df[variable].median()
        mean = df[variable].mean()
        
        # Impute missing values with median, mean, and random sample
        df[variable+"_median"] = df[variable].fillna(median)
        df[variable+"_mean"] = df[variable].fillna(mean)
        df[variable+"_random"] = df[variable]
        
        # Random sample imputation
        random_sample = df[variable].dropna().sample(df[variable].isnull().sum(), random_state=0)
        random_sample.index = df[df[variable].isnull()].index
        df.loc[df[variable].isnull(), variable+'_random'] = random_sample
        
        # Plot KDEs on the corresponding subplot
        ax = axs[idx]
        
        df[variable+"_mean"].plot(kind='kde', ax=ax, color='orange', label='Mean Imputation')
        df[variable+"_median"].plot(kind='kde', ax=ax, color='green', label='Median Imputation')
        df[variable+"_random"].plot(kind='kde', ax=ax, color='deeppink', label='Random Sample Imputation')
        df[variable].plot(kind='kde', ax=ax, color='black', label='Original')
        
        # Customize plot for the current variable
        ax.set_title(f'Distribution of {variable}')
        ax.legend(loc='best')

    # Adjust layout and display
    plt.tight_layout()
    plt.show()

# %%
# Making list of all the columns having null values
variables = ['SO2','O3','Benzene','Toluene']
impute_nan_grp(city,variables)

# %% [markdown]
# #### Changing columns with their best replacement

# %%
city.drop(["SO2", "SO2_median", "SO2_mean",
          "O3","O3_median","O3_mean",
          "Benzene","Benzene_random","Benzene_median",
          "Toluene","Toluene_median","Toluene_mean"], axis=1, inplace=True)
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0     0.92       27.64     133.36          0.00            0.02
# 1     0.97       24.55      34.06          3.68            5.50
# 2    17.40       29.07      30.70          6.80           16.40
# 3     1.70       18.59      36.08          4.43           10.14
# 4    22.10       39.33      39.31          7.01           18.89

# %%
city.tail()
# Out:
#                 City  Month   AQI  PM2.5_random  NO_random  NO2_random  \
# 29526  Visakhapatnam      6  41.0         15.02       7.68       25.06
# 29527  Visakhapatnam      6  70.0         24.38       3.42       26.06
# 29528  Visakhapatnam      6  68.0         22.91       3.45       29.53
# 29529  Visakhapatnam      6  54.0         16.64       4.05       29.26
# 29530  Visakhapatnam      7  50.0         15.00       0.40       26.85
#
#        NOx_random  CO_mean  SO2_random  O3_random  Benzene_mean  \
# 29526       19.54     0.47        8.55      23.30       2.24000
# 29527       16.53     0.52       12.72      30.14       0.74000
# 29528       18.33     0.48        8.42      30.96       0.01000
# 29529       18.80     0.52        9.84      28.30       0.00000
# 29530       14.05     0.59        2.10      17.05       3.28084
#
#        Toluene_random
# 29526           12.07
# 29527            2.21
# 29528            0.01
# 29529            0.00
# 29530            1.92

# %%
city.isnull().sum()
# Out:
# City                 0
# Month                0
# AQI               4681
# PM2.5_random         0
# NO_random            0
# NO2_random           0
# NOx_random           0
# CO_mean              0
# SO2_random           0
# O3_random            0
# Benzene_mean         0
# Toluene_random       0
# dtype: int64

# %% [markdown]
# ### Seeing if data has any outliers

# %%
import seaborn as sns
sns.histplot(city['PM2.5_random'].dropna())
# Out:
# <Axes: xlabel='PM2.5_random', ylabel='Count'>

# %%
city.boxplot(column='PM2.5_random')
# Out:
# <Axes: >

# %% [markdown]
# #### Too much outliers we have to remove them
# ***Skewed data so we have to remove using below technique***

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["PM2.5_random"].quantile(0.75) - city["PM2.5_random"].quantile(0.25)
IQR
# Out:
# 51.84

# %%
### Calculating the boundaries
lower_bridge = city["PM2.5_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["PM2.5_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-48.980000000000004, 158.38)

# %%
### Extreme Outliers
lower_bridge = city["PM2.5_random"].quantile(0.25) - (IQR*3)
upper_bridge = city["PM2.5_random"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-126.74000000000001, 236.14000000000001)

# %% [markdown]
# ### Not considring lower boundary as it only has poitive values

# %% [markdown]
# ## Remvoing Outliers

# %%
# Taking value b/w 158 and 236
city.loc[city["PM2.5_random"]>=200,"PM2.5_random"] = 200
city.boxplot(column='PM2.5_random')
# Out:
# <Axes: >

# %%
sns.histplot(city['PM2.5_random'].dropna())
# Out:
# <Axes: xlabel='PM2.5_random', ylabel='Count'>

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0     0.92       27.64     133.36          0.00            0.02
# 1     0.97       24.55      34.06          3.68            5.50
# 2    17.40       29.07      30.70          6.80           16.40
# 3     1.70       18.59      36.08          4.43           10.14
# 4    22.10       39.33      39.31          7.01           18.89

# %%
sns.histplot(city['NO_random'].dropna())
# Out:
# <Axes: xlabel='NO_random', ylabel='Count'>

# %%
city.boxplot(column='NO_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["NO_random"].quantile(0.75) - city["NO_random"].quantile(0.25)
IQR
# Out:
# 14.440000000000001

# %%
### Calculating the boundaries
lower_bridge = city["NO_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["NO_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-16.050000000000004, 41.71000000000001)

# %%
### Extreme Outliers
lower_bridge = city["NO_random"].quantile(0.25) - (IQR*3)
upper_bridge = city["NO_random"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-37.71000000000001, 63.370000000000005)

# %%
# Removing Outliers
city.loc[city["NO_random"]>=41.71000000000001,"NO_random"] = 41.71000000000001
sns.histplot(city['NO_random'].dropna())
# Out:
# <Axes: xlabel='NO_random', ylabel='Count'>

# %%
city.boxplot(column='NO_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0     0.92       27.64     133.36          0.00            0.02
# 1     0.97       24.55      34.06          3.68            5.50
# 2    17.40       29.07      30.70          6.80           16.40
# 3     1.70       18.59      36.08          4.43           10.14
# 4    22.10       39.33      39.31          7.01           18.89

# %%
sns.histplot(city['NO2_random'].dropna())
# Out:
# <Axes: xlabel='NO2_random', ylabel='Count'>

# %%
city.boxplot(column='NO2_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["NO2_random"].quantile(0.75) - city["NO2_random"].quantile(0.25)
IQR
# Out:
# 25.82

# %%
### Calculating the boundaries
lower_bridge = city["NO2_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["NO2_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-27.020000000000003, 76.26)

# %%
### Extreme Outliers
lower_bridge = city["NO2_random"].quantile(0.25) - (IQR*3)
upper_bridge = city["NO2_random"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-65.75, 114.99000000000001)

# %%
# Removing Outliers
city.loc[city["NO2_random"]>=76.26,"NO2_random"] = 76.26
sns.histplot(city['NO2_random'].dropna())
# Out:
# <Axes: xlabel='NO2_random', ylabel='Count'>

# %%
city.boxplot(column='NO2_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0     0.92       27.64     133.36          0.00            0.02
# 1     0.97       24.55      34.06          3.68            5.50
# 2    17.40       29.07      30.70          6.80           16.40
# 3     1.70       18.59      36.08          4.43           10.14
# 4    22.10       39.33      39.31          7.01           18.89

# %%
sns.histplot(city['NOx_random'].dropna())
# Out:
# <Axes: xlabel='NOx_random', ylabel='Count'>

# %%
city.boxplot(column='NOx_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["NOx_random"].quantile(0.75) - city["NOx_random"].quantile(0.25)
IQR
# Out:
# 27.205

# %%
### Calculating the boundaries
lower_bridge = city["NOx_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["NOx_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-28.0325, 80.7875)

# %%
### Extreme Outliers
lower_bridge = city["NOx_random"].quantile(0.25) - (IQR*3)
upper_bridge = city["NOx_random"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-68.84, 121.595)

# %%
# Removing Outliers
city.loc[city["NOx_random"]>=89,"NOx_random"] = 89
sns.histplot(city['NOx_random'].dropna())
# Out:
# <Axes: xlabel='NOx_random', ylabel='Count'>

# %%
city.boxplot(column='NOx_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0     0.92       27.64     133.36          0.00            0.02
# 1     0.97       24.55      34.06          3.68            5.50
# 2    17.40       29.07      30.70          6.80           16.40
# 3     1.70       18.59      36.08          4.43           10.14
# 4    22.10       39.33      39.31          7.01           18.89

# %%
city.boxplot(column='CO_mean')
# Out:
# <Axes: >

# %%
sns.histplot(city['CO_mean'].dropna())
# Out:
# <Axes: xlabel='CO_mean', ylabel='Count'>

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["CO_mean"].quantile(0.75) - city["CO_mean"].quantile(0.25)
IQR
# Out:
# 1.17

# %%
### Calculating the boundaries
lower_bridge = city["CO_mean"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["CO_mean"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-1.2149999999999999, 3.465)

# %%
### Extreme Outliers
lower_bridge = city["CO_mean"].quantile(0.25) - (IQR*3)
upper_bridge = city["CO_mean"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-2.9699999999999998, 5.22)

# %%
# Removing Outliers
city.loc[city["CO_mean"]>=3.465,'CO_mean'] = 3.465
sns.histplot(city['CO_mean'].dropna())
# Out:
# <Axes: xlabel='CO_mean', ylabel='Count'>

# %%
city.boxplot(column='CO_mean')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0    0.920       27.64     133.36          0.00            0.02
# 1    0.970       24.55      34.06          3.68            5.50
# 2    3.465       29.07      30.70          6.80           16.40
# 3    1.700       18.59      36.08          4.43           10.14
# 4    3.465       39.33      39.31          7.01           18.89

# %%
sns.histplot(city['SO2_random'].dropna())
# Out:
# <Axes: xlabel='SO2_random', ylabel='Count'>

# %%
city.boxplot(column='SO2_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["SO2_random"].quantile(0.75) - city["SO2_random"].quantile(0.25)
IQR
# Out:
# 9.48

# %%
### Calculating the boundaries
lower_bridge = city["SO2_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["SO2_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-8.56, 29.36)

# %%
### Extreme Outliers
lower_bridge = city["SO2_random"].quantile(0.25) - (IQR*3)
upper_bridge = city["SO2_random"].quantile(0.75) + (IQR*3)
(lower_bridge, upper_bridge)
# Out:
# (-22.78, 43.58)

# %%
# Removing Outliers
city.loc[city["SO2_random"]>=29.36,'SO2_random'] = 29.36
sns.histplot(city['SO2_random'].dropna())
# Out:
# <Axes: xlabel='SO2_random', ylabel='Count'>

# %%
city.boxplot(column='SO2_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0    0.920       27.64     133.36          0.00            0.02
# 1    0.970       24.55      34.06          3.68            5.50
# 2    3.465       29.07      30.70          6.80           16.40
# 3    1.700       18.59      36.08          4.43           10.14
# 4    3.465       29.36      39.31          7.01           18.89

# %%
sns.histplot(city['O3_random'].dropna())
# Out:
# <Axes: xlabel='O3_random', ylabel='Count'>

# %%
city.boxplot(column='O3_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["O3_random"].quantile(0.75) - city["O3_random"].quantile(0.25)
IQR
# Out:
# 26.669999999999998

# %%
### Calculating the boundaries
lower_bridge = city["O3_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["O3_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-21.124999999999996, 85.55499999999999)

# %%
# Removing Outliers
city.loc[city["O3_random"]>=85.55499999999999,'O3_random'] = 85.55499999999999
sns.histplot(city['O3_random'].dropna())
# Out:
# <Axes: xlabel='O3_random', ylabel='Count'>

# %%
city.boxplot(column='O3_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0    0.920       27.64     85.555          0.00            0.02
# 1    0.970       24.55     34.060          3.68            5.50
# 2    3.465       29.07     30.700          6.80           16.40
# 3    1.700       18.59     36.080          4.43           10.14
# 4    3.465       29.36     39.310          7.01           18.89

# %%
sns.histplot(city['Benzene_mean'].dropna())
# Out:
# <Axes: xlabel='Benzene_mean', ylabel='Count'>

# %%
city.boxplot(column='Benzene_mean')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["Benzene_mean"].quantile(0.75) - city["Benzene_mean"].quantile(0.25)
IQR
# Out:
# 3.040840304500585

# %%
### Calculating the boundaries
lower_bridge = city["Benzene_mean"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["Benzene_mean"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-4.321260456750878, 7.842100761251463)

# %%
# Removing Outliers
city.loc[city["Benzene_mean"]>=7.842100761251463,'Benzene_mean'] = 7.842100761251463
sns.histplot(city['Benzene_mean'].dropna())
# Out:
# <Axes: xlabel='Benzene_mean', ylabel='Count'>

# %%
city.boxplot(column='Benzene_mean')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0    0.920       27.64     85.555          0.00            0.02
# 1    0.970       24.55     34.060          3.68            5.50
# 2    3.465       29.07     30.700          6.80           16.40
# 3    1.700       18.59     36.080          4.43           10.14
# 4    3.465       29.36     39.310          7.01           18.89

# %%
sns.histplot(city['Toluene_random'].dropna())
# Out:
# <Axes: xlabel='Toluene_random', ylabel='Count'>

# %%
city.boxplot(column='Toluene_random')
# Out:
# <Axes: >

# %%
#### Let's compute the Interquantile range to calculate the boundaries
IQR = city["Toluene_random"].quantile(0.75) - city["Toluene_random"].quantile(0.25)
IQR
# Out:
# 8.59

# %%
### Calculating the boundaries
lower_bridge = city["Toluene_random"].quantile(0.25) - (IQR*1.5)
upper_bridge = city["Toluene_random"].quantile(0.75) + (IQR*1.5)
(lower_bridge, upper_bridge)
# Out:
# (-12.285, 22.075)

# %%
# Removing Outliers
city.loc[city["Toluene_random"]>=22.075,'Toluene_random'] = 22.075
sns.histplot(city['Toluene_random'].dropna())
# Out:
# <Axes: xlabel='Toluene_random', ylabel='Count'>

# %%
city.boxplot(column='Toluene_random')
# Out:
# <Axes: >

# %%
city.head()
# Out:
#         City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 0  Ahmedabad      1  NaN         51.84       0.92       18.22       17.15
# 1  Ahmedabad      1  NaN         38.26       0.97       15.69       16.46
# 2  Ahmedabad      1  NaN         53.84      17.40       19.30       29.70
# 3  Ahmedabad      1  NaN         11.75       1.70       18.48       17.97
# 4  Ahmedabad      1  NaN         31.80      22.10       21.42       37.76
#
#    CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 0    0.920       27.64     85.555          0.00            0.02
# 1    0.970       24.55     34.060          3.68            5.50
# 2    3.465       29.07     30.700          6.80           16.40
# 3    1.700       18.59     36.080          4.43           10.14
# 4    3.465       29.36     39.310          7.01           18.89

# %% [markdown]
# # Categorical Features to Numerical Features

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            29531 non-null  object
#  1   Month           29531 non-null  int32
#  2   AQI             24850 non-null  float64
#  3   PM2.5_random    29531 non-null  float64
#  4   NO_random       29531 non-null  float64
#  5   NO2_random      29531 non-null  float64
#  6   NOx_random      29531 non-null  float64
#  7   CO_mean         29531 non-null  float64
#  8   SO2_random      29531 non-null  float64
#  9   O3_random       29531 non-null  float64
#  10  Benzene_mean    29531 non-null  float64
#  11  Toluene_random  29531 non-null  float64
# dtypes: float64(10), int32(1), object(1)
# memory usage: 2.6+ MB

# %% [markdown]
# ***LABEL encoding***

# %%
city.City.unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Convert City column to string type to ensure uniformity
city['City'] = city['City'].astype(str)
# Apply Label Encoding to the 'City' column
city['City'] = label_encoder.fit_transform(city['City'])

# %%
city.head()
# Out:
#    City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  CO_mean  \
# 0     0      1  NaN         51.84       0.92       18.22       17.15    0.920
# 1     0      1  NaN         38.26       0.97       15.69       16.46    0.970
# 2     0      1  NaN         53.84      17.40       19.30       29.70    3.465
# 3     0      1  NaN         11.75       1.70       18.48       17.97    1.700
# 4     0      1  NaN         31.80      22.10       21.42       37.76    3.465
#
#    SO2_random  O3_random  Benzene_mean  Toluene_random
# 0       27.64     85.555          0.00            0.02
# 1       24.55     34.060          3.68            5.50
# 2       29.07     30.700          6.80           16.40
# 3       18.59     36.080          4.43           10.14
# 4       29.36     39.310          7.01           18.89

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            29531 non-null  int32
#  1   Month           29531 non-null  int32
#  2   AQI             24850 non-null  float64
#  3   PM2.5_random    29531 non-null  float64
#  4   NO_random       29531 non-null  float64
#  5   NO2_random      29531 non-null  float64
#  6   NOx_random      29531 non-null  float64
#  7   CO_mean         29531 non-null  float64
#  8   SO2_random      29531 non-null  float64
#  9   O3_random       29531 non-null  float64
#  10  Benzene_mean    29531 non-null  float64
#  11  Toluene_random  29531 non-null  float64
# dtypes: float64(10), int32(2)
# memory usage: 2.5 MB

# %% [markdown]
# ## Remvoing data with `NAN` AQI values

# %%
df_test = city[city['AQI'].isnull()]
df_test.head()
# Out:
#    City  Month  AQI  PM2.5_random  NO_random  NO2_random  NOx_random  CO_mean  \
# 0     0      1  NaN         51.84       0.92       18.22       17.15    0.920
# 1     0      1  NaN         38.26       0.97       15.69       16.46    0.970
# 2     0      1  NaN         53.84      17.40       19.30       29.70    3.465
# 3     0      1  NaN         11.75       1.70       18.48       17.97    1.700
# 4     0      1  NaN         31.80      22.10       21.42       37.76    3.465
#
#    SO2_random  O3_random  Benzene_mean  Toluene_random
# 0       27.64     85.555          0.00            0.02
# 1       24.55     34.060          3.68            5.50
# 2       29.07     30.700          6.80           16.40
# 3       18.59     36.080          4.43           10.14
# 4       29.36     39.310          7.01           18.89

# %%
city = city[~city['AQI'].isnull()]

# %%
city.head()
# Out:
#     City  Month    AQI  PM2.5_random  NO_random  NO2_random  NOx_random  \
# 28     0      1  209.0         83.13       6.93       28.71       33.72
# 29     0      1  328.0         79.84      13.85       28.68       41.08
# 30     0      1  514.0         94.52      24.39       32.66       52.61
# 31     0      2  782.0        135.99      41.71       42.08       84.57
# 32     0      2  914.0        178.33      41.71       35.31       72.80
#
#     CO_mean  SO2_random  O3_random  Benzene_mean  Toluene_random
# 28    3.465       29.36     59.760          0.02            0.00
# 29    3.465       29.36     85.555          0.04            0.00
# 30    3.465       29.36     85.555          0.24            0.01
# 31    3.465       29.36     85.555          0.40            0.04
# 32    3.465       29.36     85.555          0.46            0.06

# %% [markdown]
# # Test - Trian split

# %%
X = city.drop('AQI',axis=1)
X.head()
# Out:
#     City  Month  PM2.5_random  NO_random  NO2_random  NOx_random  CO_mean  \
# 28     0      1         83.13       6.93       28.71       33.72    3.465
# 29     0      1         79.84      13.85       28.68       41.08    3.465
# 30     0      1         94.52      24.39       32.66       52.61    3.465
# 31     0      2        135.99      41.71       42.08       84.57    3.465
# 32     0      2        178.33      41.71       35.31       72.80    3.465
#
#     SO2_random  O3_random  Benzene_mean  Toluene_random
# 28       29.36     59.760          0.02            0.00
# 29       29.36     85.555          0.04            0.00
# 30       29.36     85.555          0.24            0.01
# 31       29.36     85.555          0.40            0.04
# 32       29.36     85.555          0.46            0.06

# %%
y = city['AQI']
y.head()
# Out:
# 28    209.0
# 29    328.0
# 30    514.0
# 31    782.0
# 32    914.0
# Name: AQI, dtype: float64

# %%
# Split data into train and test sets
np.random.seed(42)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                   y,
                                                   test_size = 0.2)

# %% [markdown]
# # Feature Selection
# ### 1. Checking and dropping constant features
# ***Removing Low-Variance features***

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres = VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# ### No low variance feature

# %% [markdown]
# ## 2.Feature Selection with Correlation

# %%
X_train.corr()
# Out:
#                     City     Month  PM2.5_random  NO_random  NO2_random  \
# City            1.000000 -0.001149      0.080587   0.057908   -0.043480
# Month          -0.001149  1.000000      0.028332   0.036425    0.039443
# PM2.5_random    0.080587  0.028332      1.000000   0.462259    0.422966
# NO_random       0.057908  0.036425      0.462259   1.000000    0.520467
# NO2_random     -0.043480  0.039443      0.422966   0.520467    1.000000
# NOx_random      0.014362  0.019817      0.436063   0.755111    0.608727
# CO_mean        -0.126033  0.032108      0.337796   0.316718    0.282825
# SO2_random     -0.006831 -0.035965      0.233431   0.318282    0.326000
# O3_random       0.016516 -0.091553      0.182612  -0.017545    0.302533
# Benzene_mean    0.038955  0.050268      0.182507   0.252749    0.282970
# Toluene_random  0.002751  0.052707      0.205887   0.235459    0.367791
#
#                 NOx_random   CO_mean  SO2_random  O3_random  Benzene_mean  \
# City              0.014362 -0.126033   -0.006831   0.016516      0.038955
# Month             0.019817  0.032108   -0.035965  -0.091553      0.050268
# PM2.5_random      0.436063  0.337796    0.233431   0.182612      0.182507
# NO_random         0.755111  0.316718    0.318282  -0.017545      0.252749
# NO2_random        0.608727  0.282825    0.326000   0.302533      0.282970
# NOx_random        1.000000  0.310121    0.278858   0.077432      0.284780
# CO_mean           0.310121  1.000000    0.345820   0.050954      0.185162
# SO2_random        0.278858  0.345820    1.000000   0.199569      0.177520
# O3_random         0.077432  0.050954    0.199569   1.000000      0.086457
# Benzene_mean      0.284780  0.185162    0.177520   0.086457      1.000000
# Toluene_random    0.275425  0.277870    0.323687   0.157504      0.523594
#
#                 Toluene_random
# City                  0.002751
# Month                 0.052707
# PM2.5_random          0.205887
# NO_random             0.235459
# NO2_random            0.367791
# NOx_random            0.275425
# CO_mean               0.277870
# SO2_random            0.323687
# O3_random             0.157504
# Benzene_mean          0.523594
# Toluene_random        1.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)

# Save the plot as an image
plt.savefig("corr_image.png")  # Specify the desired filename and format
plt.show()

# %% [markdown]
# ### Selecting highly correlated features

# %%
# It will remove the first feature that is correlated with any other feature
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if corr_matrix.iloc[i,j] > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train,0.85)
len(set(corr_features))
# Out:
# 0

# %%
corr_features
# Out:
# set()

# %%
### Dropping highly correlated features
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
X_train.head()
# Out:
#        City  Month  PM2.5_random  NO_random  NO2_random  NOx_random  CO_mean  \
# 2405      2      9         21.81      12.19       23.75       22.67     1.64
# 7821      7      6         16.34       0.88        8.53        5.21     0.31
# 19999    19      6         71.26       3.94       15.29        4.48     2.43
# 27568    24      2         32.90       0.93        5.37        3.61     0.67
# 11403    10      3        109.99      41.71       55.71       82.08     1.42
#
#        SO2_random  O3_random  Benzene_mean  Toluene_random
# 2405        11.80      29.05       0.09000            0.07
# 7821         7.94      42.03       2.90000            0.39
# 19999        7.48      43.95       0.94000            0.93
# 27568        2.44      53.57       3.28084            5.09
# 11403       20.52      51.95       3.19000            7.16

# %%
city.shape
# Out:
# (24850, 12)

# %% [markdown]
# ## Building Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_model.predict(X_test)

rf_model.score(X_test, y_test)
# Out:
# 0.8593717102700985

# %%
rf_model.predict([[289895, 677766, 100000, 499980, 276876.85, 17684.05, 89859, 2868.10, 17799.05, 3768.28084, 189898.92]])
# Out:
# C:\Users\Shekhar Chauhan\miniconda3\envs\env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([431.22])

# %% [markdown]
# ***Applying 6 models and choosing best***
# 1. RidgeRegression
# 2. SupportVectorRegression(kernal='linear')
# 3. RandomForestRegressors
# 4. SupportVectorRegression(kernal='rbf')
# 5. Lasso
# 6. ElasticNet

# %%
"""from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Create a dictionary with regression models
regression_models = {
    "Ridge Regression": Ridge(),
    "Support Vector Regression (Linear)": SVR(kernel='linear'),
    "Random Forest Regressor": RandomForestRegressor(),
    "Support Vector Regression (RBF)": SVR(kernel='rbf'),
    "Lasso Regression": Lasso(),
    "ElasticNet": ElasticNet()
}

# Function to fit and score regression models
def fit_and_score_regressors(models, X_train, X_test, y_train, y_test):
    # Set random seed
    np.random.seed(42)
    # Dictionary to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the training data
        model.fit(X_train, y_train)
        # Evaluate the model on the test data and store the score (R^2 by default for regression)
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# Example usage:
# scores = fit_and_score_regressors(regression_models, X_train, X_test, y_train, y_test)
"""
# Out:
# 'from sklearn.linear_model import Ridge, Lasso, ElasticNet\nfrom sklearn.svm import SVR\nfrom sklearn.ensemble import RandomForestRegressor\nimport numpy as np\n\n# Create a dictionary with regression models\nregression_models = {\n    "Ridge Regression": Ridge(),\n    "Support Vector Regression (Linear)": SVR(kernel=\'linear\'),\n    "Random Forest Regressor": RandomForestRegressor(),\n    "Support Vector Regression (RBF)": SVR(kernel=\'rbf\'),\n    "Lasso Regression": Lasso(),\n    "ElasticNet": ElasticNet()\n}\n\n# Function to fit and score regression models\ndef fit_and_score_regressors(models, X_train, X_test, y_train, y_test):\n    # Set random seed\n    np.random.seed(42)\n    # Dictionary to keep model scores\n    model_scores = {}\n    # Loop through models\n    for name, model in models.items():\n        # Fit the model to the training data\n        model.fit(X_train, y_train)\n        # Evaluate the model on the test data and store the score (R^2 by default for regression)\n        model_scores[name] = model.score(X_test, y_test)\n    return model_scores\n\n# Example usage:\n# scores = fit_and_score_regressors(regression_models, X_train, X_test, y_train, y_test)\n'

# %%
"""model_scores = fit_and_score_regressors(models=regression_models,
                             X_train=X_train,
                             X_test=X_test,
                             y_train=y_train,
                             y_test=y_test)

model_scores"""
# Out:
# 'model_scores = fit_and_score_regressors(models=regression_models,\n                             X_train=X_train,\n                             X_test=X_test,\n                             y_train=y_train,\n                             y_test=y_test)\n\nmodel_scores'

# %% [markdown]
# ## Applying LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
data = city['AQI'].values
data = data.reshape(-1, 1)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Create a function to create sequences of data
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 10  # You can adjust this
X, y = create_sequences(scaled_data, seq_length)

# %%
# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(seq_length, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# C:\Users\Shekhar Chauhan\miniconda3\envs\env\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(X_train, y_train, batch_size=1, epochs=10)

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# Epoch 1/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0020
# Epoch 2/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 54s 3ms/step - loss: 0.0015
# Epoch 3/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step - loss: 0.0014
# Epoch 4/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 51s 3ms/step - loss: 0.0012
# Epoch 5/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step - loss: 0.0012
# Epoch 6/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.0013
# Epoch 7/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 51s 3ms/step - loss: 0.0013
# Epoch 8/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 51s 3ms/step - loss: 0.0014
# Epoch 9/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 56s 3ms/step - loss: 0.0012
# Epoch 10/10
# 19872/19872 ━━━━━━━━━━━━━━━━━━━━ 53s 3ms/step - loss: 0.0013
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Evaluate the model
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1335.0985154818559

# %% [markdown]
# ## Mitigation System

# %%
aqi_thresholds = {
    (0, 50): {
        "category": "Good",
        "warnings": ["No immediate action required."],
        "actions": ["Enjoy outdoor activities."]
    },
    (51, 80): {
        "category": "Moderate",
        "warnings": ["Air quality is acceptable."],
        "actions": ["Sensitive groups should consider reducing prolonged exertion."]
    },
    (81, 120): {
        "category": "Unhealthy for Sensitive Groups",
        "warnings": ["Wear masks outdoors."],
        "actions": ["Install air purifiers indoors."]
    },
    (121, 150): {
        "category": "Unhealthy",
        "warnings": ["Wear N95 masks."],
        "actions": ["Avoid outdoor activities.", "Use air purifiers."]
    },
    (151, 200): {
        "category": "Very Unhealthy",
        "warnings": ["Health alert: Everyone may experience effects."],
        "actions": ["Close windows.", "Run air purifiers at max."]
    },
    (201, 300): {
        "category": "Hazardous",
        "warnings": ["Emergency conditions."],
        "actions": ["Stay indoors.", "Use oxygen masks if necessary."]
    },
    (301, 500): {
        "category": "Severe",
        "warnings": ["Evacuate if possible."],
        "actions": ["Seek medical help for breathing issues."]
    }
}

# %%
def get_mitigation_measures(aqi):
    for (low, high), measures in aqi_thresholds.items():
        if low <= aqi <= high:
            return {
                "AQI": aqi,
                "Category": measures["category"],
                "Warnings": measures["warnings"],
                "Actions": measures["actions"]
            }
    return {
        "AQI": aqi,
        "Category": "Unhealthy",
        "Warnings": ["Wear N95 masks"],
        "Actions": ["Seek medical help for breathing issues"]
    }

# %%
# Generate mitigation advice for test predictions
mitigation_advice = [get_mitigation_measures(pred) for pred in y_pred]

# Convert to DataFrame for better visualization
import pandas as pd
mitigation_df = pd.DataFrame(mitigation_advice)

# %% [markdown]
# # AQI Predictions with Mitigation Advice:

# %%
mitigation_df
# Out:
#          AQI                        Category  \
# 0      92.31  Unhealthy for Sensitive Groups
# 1     212.18                       Hazardous
# 2     120.23                       Unhealthy
# 3     124.44                       Unhealthy
# 4      79.84                        Moderate
# ...      ...                             ...
# 4965   64.09                        Moderate
# 4966   83.58  Unhealthy for Sensitive Groups
# 4967  185.92                  Very Unhealthy
# 4968   84.57  Unhealthy for Sensitive Groups
# 4969   97.40  Unhealthy for Sensitive Groups
#
#                                               Warnings  \
# 0                               [Wear masks outdoors.]
# 1                              [Emergency conditions.]
# 2                                     [Wear N95 masks]
# 3                                    [Wear N95 masks.]
# 4                         [Air quality is acceptable.]
# ...                                                ...
# 4965                      [Air quality is acceptable.]
# 4966                            [Wear masks outdoors.]
# 4967  [Health alert: Everyone may experience effects.]
# 4968                            [Wear masks outdoors.]
# 4969                            [Wear masks outdoors.]
#
#                                                 Actions
# 0                      [Install air purifiers indoors.]
# 1       [Stay indoors., Use oxygen masks if necessary.]
# 2              [Seek medical help for breathing issues]
# 3       [Avoid outdoor activities., Use air purifiers.]
# 4     [Sensitive groups should consider reducing pro...
# ...                                                 ...
# 4965  [Sensitive groups should consider reducing pro...
# 4966                   [Install air purifiers indoors.]
# 4967        [Close windows., Run air purifiers at max.]
# 4968                   [Install air purifiers indoors.]
# 4969                   [Install air purifiers indoors.]
#
# [4970 rows x 4 columns]

# %% [markdown]
# ## Alert System

# %%
def send_alert(aqi):
    measures = get_mitigation_measures(aqi)
    message = f"""
    ALERT! AQI Level: {aqi} ({measures['Category']})
    Warnings: {', '.join(measures['Warnings'])}
    Recommended Actions: {', '.join(measures['Actions'])}
    """
    print(message)  # Email Bhej dega.....


for pred in y_pred:
    if pred > 150:
        send_alert(pred)
# Out:
#     ALERT! AQI Level: 212.18 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 156.32 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 352.05 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 155.46 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 268.88 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 352.04 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 152.91 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 444.4 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 297.2 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 192.37 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 409.81 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 215.0 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 159.24 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 160.55 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 307.74 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 171.66 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 235.43 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 275.22 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 245.55 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 244.09 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 240.2 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 331.69 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 170.46 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 523.0 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 157.24 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 242.4 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 629.76 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 166.38 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 318.32 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 194.62 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 276.07 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 446.18 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 457.45 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 179.09 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 232.22 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 218.84 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 219.59 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 152.33 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 243.3 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 283.29 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 296.7 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 420.8 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 224.94 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 222.33 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 319.91 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 286.57 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 375.41 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 767.53 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 178.42 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 209.5 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 397.76 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 308.03 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 186.73 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 209.51 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 446.67 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 177.48 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 177.91 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 338.25 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 382.09 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 199.65 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 171.43 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 468.15 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 162.7 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 275.72 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 388.17 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 232.56 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 173.03 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 316.05 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 302.42 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 239.77 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 190.92 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 181.87 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 462.15 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 356.92 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 237.62 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 245.03 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 175.01 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 302.17 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 260.51 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 239.52 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 167.43 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 340.84 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 195.46 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 161.29 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 211.13 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 206.12 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 325.88 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 290.35 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 1133.02 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 171.06 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 419.76 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 297.34 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 269.85 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 424.68 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 323.5 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 282.34 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 965.52 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 243.51 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 190.85 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 396.84 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 630.72 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 353.67 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 151.94 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 173.81 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 221.38 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 223.02 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 345.24 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 454.68 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 153.03 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 248.81 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 213.08 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 246.01 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 1175.65 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 352.78 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 226.66 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 479.38 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 228.83 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 977.65 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 159.66 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 288.48 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 231.13 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 232.73 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 333.24 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 167.31 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 372.23 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 244.37 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 402.9 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 447.31 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 320.18 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 441.52 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 165.89 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 315.95 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 280.18 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 240.98 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 311.5 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 203.93 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 162.77 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 389.56 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 157.11 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 290.82 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 255.65 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 339.37 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 190.05 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 730.19 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 398.69 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 236.63 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 184.02 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 343.26 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 313.48 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 161.9 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 165.12 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 159.16 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 189.05 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 274.93 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 308.1 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 313.98 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 225.54 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 188.04 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 186.82 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 150.36 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 418.9 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 304.48 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 310.83 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 379.33 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 384.47 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 177.22 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 302.38 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 156.96 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 444.01 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 192.86 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 329.6 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 257.14 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 241.45 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 226.42 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 239.17 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 227.42 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 194.42 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 500.24 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 241.79 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 318.37 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 227.23 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 210.18 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 669.91 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 406.41 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 1094.92 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 263.9 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 221.85 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 226.34 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 322.15 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 334.96 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 221.92 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 172.55 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 331.59 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 185.6 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 387.58 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 397.25 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 298.04 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 210.45 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 579.68 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 188.14 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 217.56 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 290.68 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 194.53 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 435.68 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 365.89 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 164.22 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 178.8 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 229.66 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 195.4 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 163.19 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 182.46 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 370.9 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 287.07 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 206.74 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 178.7 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 224.26 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 299.95 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 183.34 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 160.27 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 393.74 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 266.87 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 188.66 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 177.26 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 303.94 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 249.81 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 242.12 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 930.52 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 351.66 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 242.38 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 162.63 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 226.94 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 163.49 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 205.73 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 394.35 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 193.23 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 161.76 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 190.68 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 429.92 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 168.16 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 232.62 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 423.57 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 408.34 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 239.65 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 218.35 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 415.54 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 410.57 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 383.35 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 164.76 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 361.71 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 389.5 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 305.49 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 270.34 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 383.65 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 211.13 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 340.17 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 163.6 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 229.03 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 174.26 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 235.3 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 195.83 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 312.6 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 362.48 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 188.34 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 236.93 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 225.55 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 413.97 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 313.33 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 195.36 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 154.72 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 327.46 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 350.75 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 195.4 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 360.08 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 183.72 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 150.14 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 174.02 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 151.34 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 154.28 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 192.88 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 294.85 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 387.33 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 151.58 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 166.12 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 193.85 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 342.78 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 413.48 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 339.72 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 166.07 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 150.74 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 344.31 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 300.94 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 291.15 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 443.43 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 322.55 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 172.53 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 165.62 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 274.1 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 961.67 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 179.48 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 352.81 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 163.13 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 369.4 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 422.22 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 437.14 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 214.46 (Hazardous)
# ...
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 383.83 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 437.28 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 213.88 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 237.36 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 219.29 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 295.49 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 174.72 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 414.83 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 188.5 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 313.47 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 152.28 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 411.41 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 157.59 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 523.1 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 502.47 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 284.65 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 399.09 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 227.27 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 339.26 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 151.57 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 341.33 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 163.04 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 151.03 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 251.16 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 468.96 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 163.56 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 171.88 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 245.79 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 412.12 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 383.69 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 199.49 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 153.11 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 426.52 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 214.65 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 262.1 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 152.25 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 290.4 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 324.17 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 400.49 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 408.2 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 153.73 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 153.97 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 318.14 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 412.82 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 241.46 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 358.54 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 170.13 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 269.28 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 209.49 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 280.46 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 240.15 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 295.63 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 154.86 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 157.97 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 198.66 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 300.23 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 211.08 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 256.08 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 191.39 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 332.7 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 256.49 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 155.26 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 210.94 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 238.38 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 385.7 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 293.01 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 240.8 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 466.75 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 251.68 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 568.82 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 404.89 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 161.71 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 1072.53 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 156.87 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 239.38 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 154.52 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 152.42 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 160.06 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 290.34 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 290.45 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 396.64 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 427.23 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 341.51 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 166.71 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 200.41 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 1340.56 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 229.17 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 185.71 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 461.82 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 243.02 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 168.67 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 501.71 (Unhealthy)
#     Warnings: Wear N95 masks
#     Recommended Actions: Seek medical help for breathing issues
#
#
#     ALERT! AQI Level: 281.09 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 244.18 (Hazardous)
#     Warnings: Emergency conditions.
#     Recommended Actions: Stay indoors., Use oxygen masks if necessary.
#
#
#     ALERT! AQI Level: 462.92 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 154.27 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 164.93 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 175.5 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.
#
#
#     ALERT! AQI Level: 400.44 (Severe)
#     Warnings: Evacuate if possible.
#     Recommended Actions: Seek medical help for breathing issues.
#
#
#     ALERT! AQI Level: 185.92 (Very Unhealthy)
#     Warnings: Health alert: Everyone may experience effects.
#     Recommended Actions: Close windows., Run air purifiers at max.

# %% [markdown]
# ### Alerting beforehand

# %%
import pandas as pd

# Calculate monthly averages from available data
historical_monthly_avg = city.groupby('Month')['AQI'].mean().to_dict()

def predict_aqi(month):
    """Predict AQI based on historical monthly averages"""
    return historical_monthly_avg.get(month, None)

# Enhanced alert function with trend comparison
def send_alert(month, current_aqi):
    predicted_aqi = historical_monthly_avg.get(month)
    
    if predicted_aqi is None or pd.isna(current_aqi):
        return
    
    measures = get_mitigation_measures(current_aqi)
    
    message = f"""
    {'!'*20} AQI ALERT {'!'*20}
    Month: {month}
    Current AQI: {current_aqi:.1f}
    Historical Average: {predicted_aqi:.1f}
    Deviation: {(current_aqi - predicted_aqi)/predicted_aqi:.0%}
    
    Category: {measures['Category']}
    Warnings: {', '.join(measures['Warnings'])}
    Actions Required: {', '.join(measures['Actions'])}
    """
    print(message)

# Generate alerts for all months in dataset
for month in city['Month'].unique():
    current_aqi = city[city['Month'] == month]['AQI'].mean()
    
    if current_aqi > 150:
        send_alert(month, current_aqi)
# Out:
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 1
#     Current AQI: 231.7
#     Historical Average: 231.7
#     Deviation: 0%
#
#     Category: Hazardous
#     Warnings: Emergency conditions.
#     Actions Required: Stay indoors., Use oxygen masks if necessary.
#
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 2
#     Current AQI: 202.9
#     Historical Average: 202.9
#     Deviation: 0%
#
#     Category: Hazardous
#     Warnings: Emergency conditions.
#     Actions Required: Stay indoors., Use oxygen masks if necessary.
#
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 3
#     Current AQI: 164.7
#     Historical Average: 164.7
#     Deviation: 0%
#
#     Category: Very Unhealthy
#     Warnings: Health alert: Everyone may experience effects.
#     Actions Required: Close windows., Run air purifiers at max.
#
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 10
#     Current AQI: 188.6
#     Historical Average: 188.6
#     Deviation: 0%
#
#     Category: Very Unhealthy
#     Warnings: Health alert: Everyone may experience effects.
#     Actions Required: Close windows., Run air purifiers at max.
#
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 11
#     Current AQI: 241.7
#     Historical Average: 241.7
#     Deviation: 0%
#
#     Category: Hazardous
#     Warnings: Emergency conditions.
#     Actions Required: Stay indoors., Use oxygen masks if necessary.
#
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 12
#     Current AQI: 227.1
#     Historical Average: 227.1
#     Deviation: 0%
#
#     Category: Hazardous
#     Warnings: Emergency conditions.
#     Actions Required: Stay indoors., Use oxygen masks if necessary.

# %%
def predict_future_aqi(target_month):
    """Predict next month's AQI using simple moving average"""
    historical_values = city[city['Month'] == target_month]['AQI']
    
    if len(historical_values) == 0:
        return None
        
    # Simple moving average prediction
    return historical_values.mean()

# Example usage for month 3 prediction
next_month = 3
prediction = predict_future_aqi(next_month)

if prediction and prediction > 150:
    print(f"Predicted AQI for month {next_month}: {prediction:.1f}")
    send_alert(next_month, prediction)
# Out:
# Predicted AQI for month 3: 164.7
#
#     !!!!!!!!!!!!!!!!!!!! AQI ALERT !!!!!!!!!!!!!!!!!!!!
#     Month: 3
#     Current AQI: 164.7
#     Historical Average: 164.7
#     Deviation: 0%
#
#     Category: Very Unhealthy
#     Warnings: Health alert: Everyone may experience effects.
#     Actions Required: Close windows., Run air purifiers at max.

# %%
import numpy as np
y_pred = np.array(y_pred).tolist()

# %% [markdown]
# ## Uploading data on firebase

# %%
import firebase_admin
from firebase_admin import credentials, db
import pandas as pd

# Initialize Firebase App
def initialize_firebase():
    try:
        if not firebase_admin._apps:
            cred = credentials.Certificate("n-kings-project-id-firebase-adminsdk-fbsvc-04d8a0117e.json")
            firebase_admin.initialize_app(cred, {
                'databaseURL': 'https://n-kings-project-id-default-rtdb.asia-southeast1.firebasedatabase.app/'  # Verify this URL
            })
        print("Firebase initialized successfully.")
    except Exception as e:
        print(f"Firebase initialization failed: {str(e)}")



# Upload Mitigation Advice
def upload_mitigation_advice(mitigation_df):
    try:
        ref = db.reference('/mitigation_advice')
        if not isinstance(mitigation_df, pd.DataFrame) or mitigation_df.empty:
            raise ValueError("Invalid or empty DataFrame provided for mitigation advice.")

        advice_dict = mitigation_df.to_dict(orient='records')
        ref.set(advice_dict)
        print(f"Successfully uploaded {len(advice_dict)} mitigation records.")
    except Exception as e:
        print(f"Upload failed: {str(e)}")

#  Upload Alert History
def upload_alerts(y_pred):
    try:
        ref = db.reference('/alerts')
        if not isinstance(y_pred, list) or not y_pred:
            raise ValueError("Invalid or empty predictions list provided.")

        alerts = [get_mitigation_measures(pred) for pred in y_pred]
        
        for idx, alert in enumerate(alerts):
            ref.child(f'alert_{idx}').set(alert)
        
        print(f"Successfully uploaded {len(alerts)} alerts.")
    except Exception as e:
        print(f"Alert upload failed: {str(e)}")

# Main Execution
if __name__ == "__main__":
    # Initialize Firebase connection
    initialize_firebase()
    
    # Check if variables exist before uploading data
    try:
        if 'city' in globals() and isinstance(city, pd.DataFrame):
            upload_aqi_data(city)
        else:
            print("Skipping AQI data upload: 'city' DataFrame not found.")

        if 'y_pred' in globals() and isinstance(y_pred, list):
            mitigation_advice = [get_mitigation_measures(pred) for pred in y_pred]
            mitigation_df = pd.DataFrame(mitigation_advice)
            upload_mitigation_advice(mitigation_df)
            upload_alerts(y_pred)
        else:
            print("Skipping alerts and mitigation upload: 'y_pred' list not found.")

        print("All data uploaded to Firebase.")
    except Exception as e:
        print(f"Main execution failed: {str(e)}")
# Out:
# Firebase initialized successfully.
# Upload failed: Invalid data; couldn't parse key beginning at 1:40. Key value can't be empty or contain $ # [ ] / or .
# Successfully uploaded 4970 mitigation records.
# Successfully uploaded 4970 alerts.
# All data uploaded to Firebase.
